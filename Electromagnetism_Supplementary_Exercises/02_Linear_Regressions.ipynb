# %% [markdown]
# Suppose atoms behaved completely classically (that is quantum effects did not matter), could you figure out what element an atom was by measuring the speed and position of an orbiting electron? Let's use linear regression to find out which element we are looking at! Look at the DSECOP project "[machine learning workflow](https://github.com/GDS-Education-Community-of-Practice/DSECOP/tree/main/Machine_Learning_Workflow)" for a more thorough introduction if you are unfamiliar.

# %% [markdown]
# Let's start by defining some necessary constants. We choose units to make the numbers easy to work with.

# %%
#electron mass (MeV/c^2)
electron_mass=.51099895000
#Q/m charge mass ratio (e /(MeVc^-2))
charge_mass_ratio=1/.51099895000
#electron charge (in elementary charge e)
electron_charge= -1
#Coulomb's constant (nm MeV/e^2)
k=1.44*10**-6

# %% [markdown]
# Question 1. Using Newton's law $F=ma$ and Coulomb's law $F=kq_e\frac{Q}{r^2}$ (where $q_e$ is the charge of the electron and $Q$ is the charge of the nucleus) express $a$ in terms of $r^{-2}$

# %% [markdown]
# Question 2. Import *electron_data.csv* as a Pandas dataframe and create a vector for the regression variable $r^{-2}$

# %% [markdown]
# Question 3. Do a linear regression to extract the weights. After multiplying by the constants what do you get? What atom has this many protons?
